# %%
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np
from time import sleep
from random import randint

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=config.client_id,
                                                           client_secret=config.client_secret))

playlist = sp.user_playlist_tracks("spotify", "2LOxEzC4KmoWJ9NhW0kz5M",market="GB")

# %%
track=get_playlist_tracks("spotify","2LOxEzC4KmoWJ9NhW0kz5M")

# %%
with open('track.json', 'w') as f:
    json.dump(track, f, indent=4)

# %%
song= track[4]["track"]["name"]
artist= track[4]["track"]["artists"][0]["name"]
uri= track[4]["track"]["uri"]
# Out:
# 'spotify:track:5NwkWwfRJaT55hEPtCmJHx'

# %%
songs= []
artists=[]
uris=[]
for i in range(len(track)):
    song= track[i]["track"]["name"]
    artist= track[i]["track"]["artists"][0]["name"]
    uri= track[4]["track"]["uri"]
    songs.append(song)
    artists.append(artist)
    uris.append(uri)

# %%
df_song_artist= pd.DataFrame({"songs":songs,"artists":artists,"uris":uris})
df_song_artist
# Out:
#                                     songs          artists  \
# 0     Bohemian Rhapsody - Remastered 2011            Queen
# 1                     Sweet Child O' Mine    Guns N' Roses
# 2                 Smells Like Teen Spirit          Nirvana
# 3               Imagine - Remastered 2010      John Lennon
# 4                        You're the Voice     John Farnham
# ..                                    ...              ...
# 987                      Running on Empty   Jackson Browne
# 988  Every Little Thing She Does Is Magic       The Police
# 989                  Doo Wop (That Thing)  Ms. Lauryn Hill
# 990             The Boys Are Back In Town       Thin Lizzy
# 991                                Desire               U2
#
#                                      uris
# 0    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 1    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 2    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 3    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 4    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# ..                                    ...
# 987  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 988  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 989  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 990  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 991  spotify:track:5NwkWwfRJaT55hEPtCmJHx
#
# [992 rows x 3 columns]

# %%
features= []
for i in range(len(track)):
   if i%100==0:
      seconds_to_wait = randint(0,1)
      print("Wating {} seconds before scraping the next website!".format(seconds_to_wait))
      sleep(seconds_to_wait)
   feature= sp.audio_features(uris[i])
   features.append(feature)
# Out:
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!
# Wating 0 seconds before scraping the next website!
# Wating 1 seconds before scraping the next website!

# %%
test_features= features

# %%
df2= pd.DataFrame(test_features)
df2= df2[0]
df2[0]
# Out:
# {'danceability': 0.369,
#  'energy': 0.762,
#  'key': 10,
#  'loudness': -8.993,
#  'mode': 1,
#  'speechiness': 0.0464,
#  'acousticness': 0.22,
#  'instrumentalness': 2.8e-05,
#  'liveness': 0.579,
#  'valence': 0.644,
#  'tempo': 84.957,
#  'type': 'audio_features',
#  'id': '5NwkWwfRJaT55hEPtCmJHx',
#  'uri': 'spotify:track:5NwkWwfRJaT55hEPtCmJHx',
#  'track_href': 'https://api.spotify.com/v1/tracks/5NwkWwfRJaT55hEPtCmJHx',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NwkWwfRJaT55hEPtCmJHx',
#  'duration_ms': 302107,
#  'time_signature': 4}

# %%
data=[]
df3= pd.DataFrame(data,columns=["danceability","energy","key","loudness","mode","speechiness","acousticness","instrumentalness","liveness"
,"valence","tempo","type","id","uri","track_href","analysis_url","duration_ms","time_signature"])
df3
# Out:
# Empty DataFrame
# Columns: [danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature]
# Index: []

# %%
for i in range(len(features)):
    df3= df3.append(df2[i],ignore_index=True)

# %%
df3
# Out:
#      danceability  energy key  loudness mode  speechiness  acousticness  \
# 0           0.369   0.762  10    -8.993    1       0.0464          0.22
# 1           0.369   0.762  10    -8.993    1       0.0464          0.22
# 2           0.369   0.762  10    -8.993    1       0.0464          0.22
# 3           0.369   0.762  10    -8.993    1       0.0464          0.22
# 4           0.369   0.762  10    -8.993    1       0.0464          0.22
# ..            ...     ...  ..       ...  ...          ...           ...
# 987         0.369   0.762  10    -8.993    1       0.0464          0.22
# 988         0.369   0.762  10    -8.993    1       0.0464          0.22
# 989         0.369   0.762  10    -8.993    1       0.0464          0.22
# 990         0.369   0.762  10    -8.993    1       0.0464          0.22
# 991         0.369   0.762  10    -8.993    1       0.0464          0.22
#
#      instrumentalness  liveness  valence   tempo            type  \
# 0            0.000028     0.579    0.644  84.957  audio_features
# 1            0.000028     0.579    0.644  84.957  audio_features
# 2            0.000028     0.579    0.644  84.957  audio_features
# 3            0.000028     0.579    0.644  84.957  audio_features
# 4            0.000028     0.579    0.644  84.957  audio_features
# ..                ...       ...      ...     ...             ...
# 987          0.000028     0.579    0.644  84.957  audio_features
# 988          0.000028     0.579    0.644  84.957  audio_features
# 989          0.000028     0.579    0.644  84.957  audio_features
# 990          0.000028     0.579    0.644  84.957  audio_features
# 991          0.000028     0.579    0.644  84.957  audio_features
#
#                          id                                   uri  \
# 0    5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 1    5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 2    5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 3    5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 4    5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# ..                      ...                                   ...
# 987  5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 988  5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 989  5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 990  5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 991  5NwkWwfRJaT55hEPtCmJHx  spotify:track:5NwkWwfRJaT55hEPtCmJHx
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 1    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 2    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 3    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 4    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# ..                                                 ...
# 987  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 988  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 989  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 990  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 991  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 1    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 2    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 3    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 4    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# ..                                                 ...         ...
# 987  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 988  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 989  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 990  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 991  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 987              4
# 988              4
# 989              4
# 990              4
# 991              4
#
# [992 rows x 18 columns]

# %%
spotify_data= pd.concat([df_song_artist, df3],axis=1).reset_index(drop=True)

spotify_data
# Out:
#                                     songs          artists  \
# 0     Bohemian Rhapsody - Remastered 2011            Queen
# 1                     Sweet Child O' Mine    Guns N' Roses
# 2                 Smells Like Teen Spirit          Nirvana
# 3               Imagine - Remastered 2010      John Lennon
# 4                        You're the Voice     John Farnham
# ..                                    ...              ...
# 987                      Running on Empty   Jackson Browne
# 988  Every Little Thing She Does Is Magic       The Police
# 989                  Doo Wop (That Thing)  Ms. Lauryn Hill
# 990             The Boys Are Back In Town       Thin Lizzy
# 991                                Desire               U2
#
#                                      uris  danceability  energy key  loudness  \
# 0    spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# 1    spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# 2    spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# 3    spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# 4    spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# ..                                    ...           ...     ...  ..       ...
# 987  spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# 988  spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# 989  spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# 990  spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
# 991  spotify:track:5NwkWwfRJaT55hEPtCmJHx         0.369   0.762  10    -8.993
#
#     mode  speechiness  acousticness  ...  liveness  valence   tempo  \
# 0      1       0.0464          0.22  ...     0.579    0.644  84.957
# 1      1       0.0464          0.22  ...     0.579    0.644  84.957
# 2      1       0.0464          0.22  ...     0.579    0.644  84.957
# 3      1       0.0464          0.22  ...     0.579    0.644  84.957
# 4      1       0.0464          0.22  ...     0.579    0.644  84.957
# ..   ...          ...           ...  ...       ...      ...     ...
# 987    1       0.0464          0.22  ...     0.579    0.644  84.957
# 988    1       0.0464          0.22  ...     0.579    0.644  84.957
# 989    1       0.0464          0.22  ...     0.579    0.644  84.957
# 990    1       0.0464          0.22  ...     0.579    0.644  84.957
# 991    1       0.0464          0.22  ...     0.579    0.644  84.957
#
#                type                      id  \
# 0    audio_features  5NwkWwfRJaT55hEPtCmJHx
# 1    audio_features  5NwkWwfRJaT55hEPtCmJHx
# 2    audio_features  5NwkWwfRJaT55hEPtCmJHx
# 3    audio_features  5NwkWwfRJaT55hEPtCmJHx
# 4    audio_features  5NwkWwfRJaT55hEPtCmJHx
# ..              ...                     ...
# 987  audio_features  5NwkWwfRJaT55hEPtCmJHx
# 988  audio_features  5NwkWwfRJaT55hEPtCmJHx
# 989  audio_features  5NwkWwfRJaT55hEPtCmJHx
# 990  audio_features  5NwkWwfRJaT55hEPtCmJHx
# 991  audio_features  5NwkWwfRJaT55hEPtCmJHx
#
#                                       uri  \
# 0    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 1    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 2    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 3    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 4    spotify:track:5NwkWwfRJaT55hEPtCmJHx
# ..                                    ...
# 987  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 988  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 989  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 990  spotify:track:5NwkWwfRJaT55hEPtCmJHx
# 991  spotify:track:5NwkWwfRJaT55hEPtCmJHx
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 1    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 2    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 3    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 4    https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# ..                                                 ...
# 987  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 988  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 989  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 990  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
# 991  https://api.spotify.com/v1/tracks/5NwkWwfRJaT5...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 1    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 2    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 3    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 4    https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# ..                                                 ...         ...
# 987  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 988  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 989  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 990  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
# 991  https://api.spotify.com/v1/audio-analysis/5Nwk...      302107
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 987              4
# 988              4
# 989              4
# 990              4
# 991              4
#
# [992 rows x 21 columns]

# %%
spotify_data.to_csv("spotify_data.csv")
